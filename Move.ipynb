# %%
import nbformat as nbf

text="Data"
python="Questions"

# paths
txt_path = f"{text}.txt"
ipynb_path = f"{python}.ipynb"
# read questions
with open(txt_path, "r") as f:
    lines = [l.strip() for l in f if l.strip()]
# load notebook
nb = nbf.read(ipynb_path, as_version=4)
# append cells
for q in lines:
    # markdown cell
    nb.cells.append(nbf.v4.new_markdown_cell(f"#### {q}"))  
    # python cell (empty placeholder)
    nb.cells.append(nbf.v4.new_code_cell("""query=\"\"\" 

\"\"\"
cur.execute(query)
data=cur.fetchall()
columns = [col[0] for col in cur.description]
df = pd.DataFrame(data, columns=columns)
df = df.rename(columns={col: f"{col} (c{i+1})" for i, col in enumerate(df.columns)})
display(df.head().style.hide(axis="index").set_properties(**{'text-align': 'left'}).set_table_styles([{'selector': 'th', 'props': [('text-align', 'center')]},{'selector': 'th', 'props': [('border', '1.5px solid white')]},{'selector': 'td', 'props': [('border', '1px solid white')]}]))
"""))
# save back
nbf.write(nb, ipynb_path)
